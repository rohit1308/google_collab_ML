# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit1308/google_collab_ML/blob/main/uci_dataset_22_09_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# redict whether annual income of an individual exceeds $50K/yr based on census data. Also known as "Census Income" dataset.
#
# Dataset Characteristics
# Multivariate
#
# Subject Area
# Social Science
#
# Associated Tasks
# Classification
#
# Feature Type
# Categorical, Integer
#
# # Instances
# 48842
#
# # Features
# 14
#
#
# http://archive.ics.uci.edu/dataset/2/adult
# ---------
# describe the data set
# r2 score to check if relationship between feature is usefull
# data target is classification
# missing values yes
# final weight --

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/adult.data")
df.head()
#name of columns are incorrect
#change the column names
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.describe()
# Out:
#                  39         77516            13          2174             0  \
# count  32560.000000  3.256000e+04  32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05     10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05      2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  40
# count  32560.000000
# mean      40.437469
# std       12.347618
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
columns = [
"age",
"workclass",
"fnlwgt",
"education",
"education-num",
"marital-status",
"occupation",
"relationship",
"race",
"sex",
"capital-gain",
"capital-loss",
"hours-per-week",
"native-country",
"income"
]

df=pd.read_csv("/content/adult.data",names=columns)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# not reading properly column names are incorect placed.

# %%
df=pd.read_csv("/content/adult.data",names=columns,skipinitialspace=True)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# Mapping Examples education_num
# Common values correspond directly to years or relative ranks of schooling:1: Preschool5: 9th grade9: High school graduate (HS-grad)10: Some-college13: Bachelors degree14: Masters degree16: Doctorate

# %%
df.sample(10)
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 14935   23         State-gov   61743    5th-6th              3
# 25806   49                 ?   31478    7th-8th              4
# 12574   56           Private  219762    HS-grad              9
# 27356   39           Private  211154    HS-grad              9
# 12762   65           Private  194456  Bachelors             13
# 17077   54      Self-emp-inc  108435  Bachelors             13
# 17343   38           Private  436361    HS-grad              9
# 20969   34           Private   36385    Masters             14
# 19369   63           Private   64544  Bachelors             13
# 5516    43  Self-emp-not-inc  183479    HS-grad              9
#
#            marital-status        occupation   relationship   race     sex  \
# 14935       Never-married  Transport-moving  Not-in-family  White    Male
# 25806  Married-civ-spouse                 ?        Husband  White    Male
# ...

# %% [markdown]
# uci website shoing 14 feature but sample showing 15?
# last one is target variable income,cant be counted as feature

# %%
df.info()
#object type 9 int 6
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# no missing value

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum() #df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
#question mark in dataset
(df=='?').sum() #boolean mark
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %%
#replace ? with na
df.replace("?",np.nan,inplace=True)
df.sample(12)
# Out:
#        age     workclass  fnlwgt     education  education-num  \
# 16296   19       Private  211355       HS-grad              9
# 9939    43   Federal-gov  325706   Prof-school             15
# 15388   35       Private  188888     Bachelors             13
# 30461   34       Private  185216  Some-college             10
# 21807   26       Private   63577  Some-college             10
# 16422   50  Self-emp-inc  158294   Prof-school             15
# 21897   25       Private  195481       HS-grad              9
# 25915   33       Private  182926     Bachelors             13
# 2544    19           NaN  192773  Some-college             10
# 19421   26       Private  167848       HS-grad              9
# 2200    65       Private   90377     Assoc-voc             11
# 8680    25       Private  177499     Bachelors             13
#
#            marital-status         occupation    relationship  \
# 16296       Never-married       Adm-clerical       Own-child
# ...

# %%
#proportion of people with salary
df["income"].value_counts()
# Out:
# income
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %%
df["income"].value_counts(normalize=True)
#class inbalance hi
#under sampling and oversampling is required as there is inbalancing
# Out:
# income
# <=50K    0.75919
# >50K     0.24081
# Name: proportion, dtype: float64

# %%
#how to find probablity
#above one normalized is also p(a)
#other method
(df["income"]== ">50K").astype(int).mean()
# Out:
# np.float64(0.2408095574460244)

# %%
#distribution on df
df["age"].hist(bins=30)
plt.xlabel("age")
plt.ylabel("number of people")
plt.title("age distribution")
plt.show()

# %% [markdown]
# skewed toward right
# most of the people are in 25-40

# %%
df["age"].mean(), df["age"].median()
# Out:
# (np.float64(38.58164675532078), 37.0)

# %%
df["capital-gain"].mean(), df["capital-gain"].median()
# Out:
# (np.float64(1077.6488437087312), 0.0)

# %% [markdown]
# median 0 :alteast 50% people does not have gain

# %%
df["capital-gain"].hist(bins=30)
plt.xlabel("capital-gain")
plt.ylabel("number of people")
plt.title("capital-gain distribution")
plt.show()
#30000 people does not have any gain

# %%
#variance of age
df["age"].var(),df["age"].std()
#mean 38 se 13 (sigma 1) plus minus me sara data hi 68%
# Out:
# (186.06140024879625, 13.640432553581146)

# %%
#let consider this sample as overall population and create sample out of it
sample=df["age"].sample(50)
sample.mean(),df["age"].mean()
# Out:
# (np.float64(38.52), np.float64(38.58164675532078))

# %% [markdown]
# sample ka mean har bar alag hoga
# isko kaise handle karenge
# averages of sample
# central limit therom:distribution of sample means approaches to normal ditribution as sample size gets larger

# %%
#sampling variability
means=[]
for _ in range(5000):
  sample=df["age"].sample(50)
  means.append(sample.mean())
plt.hist(means,bins=30)
# Out:
# (array([  1.,   4.,   7.,   9.,  16.,  31.,  56., 107., 172., 230., 317.,
#         393., 470., 525., 509., 469., 426., 398., 282., 213., 135.,  93.,
#          59.,  33.,  21.,   9.,   8.,   2.,   2.,   3.]),
#  array([31.4, 31.9, 32.4, 32.9, 33.4, 33.9, 34.4, 34.9, 35.4, 35.9, 36.4,
#         36.9, 37.4, 37.9, 38.4, 38.9, 39.4, 39.9, 40.4, 40.9, 41.4, 41.9,
#         42.4, 42.9, 43.4, 43.9, 44.4, 44.9, 45.4, 45.9, 46.4]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# means ka mean bhi 38 ke aspas hi
#
# this is clt

# %%
population=np.random.exponential(scale=1,size=100000)
plt.hist(population,bins=50)
# Out:
# (array([1.9360e+04, 1.5543e+04, 1.2748e+04, 1.0036e+04, 8.0570e+03,
#         6.6960e+03, 5.2560e+03, 4.2230e+03, 3.4430e+03, 2.8230e+03,
#         2.2600e+03, 1.9300e+03, 1.4420e+03, 1.1840e+03, 9.8100e+02,
#         8.0600e+02, 6.3100e+02, 4.8600e+02, 4.0700e+02, 3.2700e+02,
#         2.4200e+02, 2.1600e+02, 1.7200e+02, 1.4600e+02, 1.1200e+02,
#         1.0500e+02, 6.4000e+01, 6.0000e+01, 3.9000e+01, 4.4000e+01,
#         2.3000e+01, 3.0000e+01, 1.8000e+01, 1.5000e+01, 1.8000e+01,
#         9.0000e+00, 7.0000e+00, 8.0000e+00, 8.0000e+00, 3.0000e+00,
#         4.0000e+00, 6.0000e+00, 2.0000e+00, 3.0000e+00, 4.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([7.98907100e-06, 2.14215978e-01, 4.28423967e-01, 6.42631956e-01,
#         8.56839944e-01, 1.07104793e+00, 1.28525592e+00, 1.49946391e+00,
#         1.71367190e+00, 1.92787989e+00, 2.14208788e+00, 2.35629587e+00,
#         2.57050386e+00, 2.78471184e+00, 2.99891983e+00, 3.21312782e+00,
# ...

# %%
means=[]
for _ in range(5000):
  sample=np.random.choice(population,size=100)
  means.append(sample.mean())
plt.hist(means,bins=30)
#plt.show()
# Out:
# (array([  6.,   7.,  16.,  35.,  53., 107., 159., 203., 248., 336., 401.,
#         420., 464., 436., 443., 372., 280., 270., 187., 174., 132.,  93.,
#          60.,  30.,  28.,  19.,  12.,   1.,   4.,   4.]),
#  array([0.7083333 , 0.73013763, 0.75194196, 0.77374629, 0.79555061,
#         0.81735494, 0.83915927, 0.8609636 , 0.88276792, 0.90457225,
#         0.92637658, 0.94818091, 0.96998524, 0.99178956, 1.01359389,
#         1.03539822, 1.05720255, 1.07900687, 1.1008112 , 1.12261553,
#         1.14441986, 1.16622418, 1.18802851, 1.20983284, 1.23163717,
#         1.25344149, 1.27524582, 1.29705015, 1.31885448, 1.34065881,
#         1.36246313]),
#  <BarContainer object of 30 artists>)
